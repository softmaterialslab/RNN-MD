# %% [markdown]
# ## RNN-MD Rugged experiment

# %% [markdown]
# ### Load the module and load configuration from rugged.yaml file

# %%
from model.RNN_MD import RNN_MD
rnn_md = RNN_MD(experiment='rugged')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2.1.0
# /device:GPU:0
# Num GPUs Available:  1
# 1 Physical GPUs, 1 Logical GPUs
# 2.1.0
# /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# ### Load dataset

# %%
rnn_md.load_data()
# Out:
# Total # of simulation:620
# (620, 20000, 6)
# 310
# 310
# (58500, 5)
# (58500,)
# input:  (58500, 5)
# Output (58500,)
# Train input:  (46800, 5, 1)
# Train Output (46800, 1)
# Test input:  (11700, 5, 1)
# Test Output (11700, 1)

# %% [markdown]
# ### Train and save the model

# %%
rnn_md.train()
rnn_md.save_model()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method RNN_MD.loss_func of <tensorflow.python.eager.function.TfMethodTarget object at 0x000001CBC00D1988>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: code mixing tabs and spaces for intentation is not allowed
# WARNING: AutoGraph could not transform <bound method RNN_MD.loss_func of <tensorflow.python.eager.function.TfMethodTarget object at 0x000001CBC00D1988>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: code mixing tabs and spaces for intentation is not allowed
# Epoch 1, Training Loss 1.1045838255317162, Test Loss 0.07113674610264901, Elapsed time 6.74s
# ...

# %% [markdown]
# ### Load the saved model

# %%
rnn_md.load_model()
# Out:
# Model: "lstm__model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  multiple                  4352
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  128
# _________________________________________________________________
# activation (Activation)      multiple                  0
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# lstm_1 (LSTM)                multiple                  8320
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  128
# _________________________________________________________________
# activation_1 (Activation)    multiple                  0
# ...

# %% [markdown]
# ### Running a new simulation with RNN-MD and ploting it

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

rnn_md.simulate_new(testing_index=125)

fig=plt.figure(figsize=(16, 6))
plt.title(rnn_md.input_list[rnn_md.sim_])
plt.plot(rnn_md.actual_output,'r+', label='MD_dynamics', linewidth=1, markersize=3, linestyle='dashed')
plt.plot(rnn_md.predicted_output, label='MD-RNN')
plt.plot(rnn_md.Only_RNN_predicted_output, label='continous RNN')
plt.legend()
# Out:
# (195,)
# (195,)
# (195,)
