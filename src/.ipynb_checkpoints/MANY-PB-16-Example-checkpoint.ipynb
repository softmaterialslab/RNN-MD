# %% [markdown]
# ## RNN-MD Many particle (16) PB experiment

# %% [markdown]
# ### Load the module and load configuration from lj.yaml file

# %%
from model.RNN_MD import RNN_MD
rnn_md = RNN_MD(experiment='many_pb_16')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2.1.0
# /device:GPU:0
# Num GPUs Available:  1
# 1 Physical GPUs, 1 Logical GPUs
# 2.1.0
# /device:GPU:0
# Num GPUs Available:  1

# %% [markdown]
# ### Load dataset

# %%
rnn_md.load_many_particle_data()

# %% [markdown]
# ### Train and save the model

# %%
rnn_md.train()
rnn_md.save_model()

# %% [markdown]
# ### Load the saved model

# %%
rnn_md.load_model()
# Out:
# Model: "lstm__model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  multiple                  10368
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  128
# _________________________________________________________________
# activation (Activation)      multiple                  0
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# lstm_1 (LSTM)                multiple                  8320
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  128
# _________________________________________________________________
# activation_1 (Activation)    multiple                  0
# ...

# %% [markdown]
# ### Running a new simulation with RNN-MD and ploting it

# %%
rnn_md.simulate_new_many_particle(testing_index=0)
# Out:
# Actual data shape: (1996, 16, 3)
# Predicted data shape: (1996, 16, 3)

# %% [markdown]
# ### Actual movie visualization

# %%
# %matplotlib notebook
# %matplotlib notebook

import sys
sys.path.append('../scripts/')
from viz_src.Particle_viz import Particle_viz


viz_sim = Particle_viz(movie_file_name = "temp_data/actual4000x.lammpstrj")
viz_sim.get_figure()
viz_sim.start()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# ### Predicted movie visualization

# %%
# %matplotlib notebook
# %matplotlib notebook

import sys
sys.path.append('../scripts/')
from viz_src.Particle_viz import Particle_viz


viz_sim = Particle_viz(movie_file_name = "temp_data/predicted4000x.lammpstrj")
viz_sim.get_figure()
viz_sim.start()
# Out:
# <img src="data:image/png;base64,..." width="700">
